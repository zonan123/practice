# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Zhou Nan**
# software developer

# %% [markdown]
# *I am interested in data science because I would like to be an AI engineer in automotivate field.*

# %% [markdown]
# ### The following function is used to calculate the value of x to the power of y.

# %%
def my_function(x,y):
    return pow(x,y)

res = my_function(10,3)
print(res)
# Out:
# 1000

# %% [markdown]
# This text is ***really important***.
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item
# ---
# This is a link [python function](https://www.w3schools.com/python/python_functions.asp).
